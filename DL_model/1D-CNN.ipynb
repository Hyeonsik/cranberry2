# %% [markdown]
# # 1D-CNN model
# <br>
# - skeletal code: https://github.com/vitaldb/maic2020

# %% [markdown]
# ## Loading x, y

# %%
import numpy as np
import pandas as pd
import os
import pickle
import sys
sys.path.append("..")

MINUTES_AHEAD = 5
SRATE = 100 # 100Hz
LEN_INPUT = 10 # input 길이는 10초

# 2초 moving average
def moving_average(a, n=200):
    ret = np.nancumsum(a, dtype=np.float32)
    ret[n:] = ret[n:] - ret[:-n]
    return ret[n - 1:] / n

# training set 로딩
x_total_ppg, x_total_ecg = [], []
x_train = []  # ppg, ecg waveform (10s each)
y_total = []
y_train = []  # NRS 0.0 ~ 10.0


if os.path.exists('x_train_ppg.npz'):
    print('loading train...', flush=True, end='')
    x_total_ppg = np.load('x_total_ppg', allow_pickle=True)['arr_0']
    x_total_ecg = np.load('x_total_ecg', allow_pickle=True)['arr_0']
    y_train = np.load('y_train.npz')['arr_0']
    print('done', flush=True)
    
else:
    # augmentated data의 합격 여부 loading
    df_preprocess = pickle.load(open('../Preprocessing/cache/df_preprocess_total', 'rb'))
    
    
    vital_path = '../Preprocessing/NRS_vital_pickle_unzip/NRS_vital_pickle'
    row_cnt = 0
    for _, row in df_preprocess.iterrows():
        row_cnt +=1
        print('loading data',row_cnt,"...", end='')
        # vital data loading
        df_vital = pickle.load(open(vital_path+'/'+row['file_path'], 'rb')).reset_index()
        
        # 한 NRS에 대해 23개의 input 확인
        for i in range(23):
            # input이 전처리 통과한 경우
            if row[str(i+1)][0]:
                start_idx = i*5*SRATE # 500i
                end_idx = (i*5 + LEN_INPUT)*SRATE # 500i + 1000
                df_vital_input = df_vital.loc[start_idx:end_idx-1]
                #df_vital_input = df_vital_input.fillna(method='ffill').fillna(method='bfill').values
                
                pleth_inp, ecg_inp = [np.nan for j in range(LEN_INPUT*SRATE)], [np.nan for j in range(LEN_INPUT*SRATE)]
                # input의 정규화
                pleth_inp[0:df_vital_input['Pleth'].size] = df_vital_input['Pleth'].tolist()
                pleth_inp = pleth_inp - np.nanmean(pleth_inp)
                
                ecg_inp[0:df_vital_input['ECG'].size] = (df_vital_input['ECG'].tolist())
                #ecg_inp = (ecg_inp-ecg_inp.min()) / (ecg_inp.max()-ecg_inp.min())
                ecg_inp = (ecg_inp - np.nanmean(ecg_inp)) / np.nanstd(ecg_inp)
                
                x_total_ppg.append(pleth_inp)
                x_total_ecg.append(ecg_inp)
                y_total.append(int(row['file_path'][0]))

        print('completed')
    
    x_total_ppg = np.array(x_total_ppg, np.float32)        
    x_total_ecg = np.array(x_total_ecg, np.float32)
    y_total = np.array(y_total, int)
    
    print('saving...', end='', flush=True)
    np.savez_compressed('x_total_ppg.npz', x_total_ppg)
    np.savez_compressed('x_total_ecg.npz', x_total_ecg)
    np.savez_compressed('y_total.npz', y_total)
    print('done', flush=True)
# Out:
# loading data 1 ...completed
# loading data 2 ...completed
# loading data 3 ...completed
# loading data 4 ...completed
# loading data 5 ...completed
# loading data 6 ...completed
# loading data 7 ...completed
# loading data 8 ...completed
# loading data 9 ...completed
# loading data 10 ...completed
# loading data 11 ...completed
# loading data 12 ...completed
# loading data 13 ...completed
# loading data 14 ...completed
# loading data 15 ...completed
# loading data 16 ...completed
# loading data 17 ...completed
# loading data 18 ...completed
# loading data 19 ...completed
# loading data 20 ...completed
# loading data 21 ...completed
# loading data 22 ...completed
# loading data 23 ...completed
# loading data 24 ...completed
# loading data 25 ...completed
# loading data 26 ...completed
# loading data 27 ...completed
# loading data 28 ...completed
# loading data 29 ...completed
# loading data 30 ...completed
# loading data 31 ...completed
# loading data 32 ...completed
# loading data 33 ...completed
# loading data 34 ...completed
# loading data 35 ...completed
# loading data 36 ...completed
# loading data 37 ...completed
# loading data 38 ...completed
# loading data 39 ...completed
# loading data 40 ...completed
# loading data 41 ...completed
# loading data 42 ...completed
# loading data 43 ...completed
# loading data 44 ...completed
# loading data 45 ...completed
# loading data 46 ...completed
# loading data 47 ...completed
# loading data 48 ...completed
# loading data 49 ...completed
# loading data 50 ...completed
# loading data 51 ...completed
# loading data 52 ...completed
# loading data 53 ...completed
# loading data 54 ...completed
# loading data 55 ...completed
# loading data 56 ...completed
# loading data 57 ...completed
# loading data 58 ...completed
# loading data 59 ...completed
# loading data 60 ...completed
# loading data 61 ...completed
# loading data 62 ...completed
# loading data 63 ...completed
# loading data 64 ...completed
# loading data 65 ...completed
# loading data 66 ...completed
# loading data 67 ...completed
# loading data 68 ...completed
# loading data 69 ...completed
# loading data 70 ...completed
# loading data 71 ...completed
# loading data 72 ...completed
# loading data 73 ...completed
# loading data 74 ...completed
# loading data 75 ...completed
# loading data 76 ...completed
# loading data 77 ...completed
# loading data 78 ...completed
# loading data 79 ...completed
# loading data 80 ...completed
# loading data 81 ...completed
# loading data 82 ...completed
# loading data 83 ...completed
# loading data 84 ...completed
# loading data 85 ...completed
# loading data 86 ...completed
# loading data 87 ...completed
# loading data 88 ...completed
# loading data 89 ...completed
# loading data 90 ...completed
# loading data 91 ...completed
# loading data 92 ...completed
# loading data 93 ...completed
# loading data 94 ...completed
# loading data 95 ...completed
# loading data 96 ...completed
# loading data 97 ...completed
# loading data 98 ...completed
# loading data 99 ...completed
# loading data 100 ...completed
# loading data 101 ...completed
# loading data 102 ...completed
# loading data 103 ...completed
# loading data 104 ...completed
# loading data 105 ...completed
# loading data 106 ...completed
# loading data 107 ...completed
# loading data 108 ...completed
# loading data 109 ...completed
# loading data 110 ...completed
# loading data 111 ...completed
# loading data 112 ...completed
# loading data 113 ...completed
# loading data 114 ...completed
# loading data 115 ...completed
# loading data 116 ...completed
# loading data 117 ...completed
# loading data 118 ...completed
# loading data 119 ...completed
# loading data 120 ...completed
# loading data 121 ...completed
# loading data 122 ...completed
# loading data 123 ...completed
# loading data 124 ...completed
# loading data 125 ...completed
# loading data 126 ...completed
# loading data 127 ...completed
# loading data 128 ...completed
# loading data 129 ...completed
# loading data 130 ...completed
# loading data 131 ...completed
# loading data 132 ...completed
# loading data 133 ...completed
# loading data 134 ...completed
# loading data 135 ...completed
# loading data 136 ...completed
# loading data 137 ...completed
# loading data 138 ...completed
# loading data 139 ...completed
# loading data 140 ...completed
# loading data 141 ...completed
# loading data 142 ...completed
# loading data 143 ...completed
# loading data 144 ...completed
# loading data 145 ...completed
# loading data 146 ...completed
# loading data 147 ...completed
# loading data 148 ...completed
# loading data 149 ...completed
# loading data 150 ...completed
# loading data 151 ...completed
# loading data 152 ...completed
# loading data 153 ...completed
# loading data 154 ...completed
# loading data 155 ...completed
# loading data 156 ...completed
# loading data 157 ...completed
# loading data 158 ...completed
# loading data 159 ...completed
# loading data 160 ...completed
# loading data 161 ...completed
# loading data 162 ...completed
# loading data 163 ...completed
# loading data 164 ...completed
# loading data 165 ...completed
# loading data 166 ...completed
# loading data 167 ...completed
# loading data 168 ...completed
# loading data 169 ...completed
# loading data 170 ...completed
# loading data 171 ...completed
# loading data 172 ...completed
# loading data 173 ...completed
# loading data 174 ...completed
# loading data 175 ...completed
# loading data 176 ...completed
# loading data 177 ...completed
# loading data 178 ...completed
# loading data 179 ...completed
# loading data 180 ...completed
# loading data 181 ...completed
# loading data 182 ...completed
# loading data 183 ...completed
# loading data 184 ...completed
# loading data 185 ...completed
# loading data 186 ...completed
# loading data 187 ...completed
# loading data 188 ...completed
# loading data 189 ...completed
# loading data 190 ...completed
# loading data 191 ...completed
# loading data 192 ...completed
# loading data 193 ...completed
# loading data 194 ...completed
# loading data 195 ...completed
# loading data 196 ...completed
# loading data 197 ...completed
# loading data 198 ...completed
# loading data 199 ...completed
# loading data 200 ...completed
# loading data 201 ...completed
# loading data 202 ...completed
# loading data 203 ...completed
# loading data 204 ...completed
# loading data 205 ...completed
# loading data 206 ...completed
# loading data 207 ...completed
# loading data 208 ...completed
# loading data 209 ...completed
# loading data 210 ...completed
# loading data 211 ...completed
# loading data 212 ...completed
# loading data 213 ...completed
# loading data 214 ...completed
# loading data 215 ...completed
# loading data 216 ...completed
# loading data 217 ...completed
# loading data 218 ...completed
# loading data 219 ...completed
# loading data 220 ...completed
# loading data 221 ...completed
# loading data 222 ...completed
# loading data 223 ...completed
# loading data 224 ...completed
# loading data 225 ...completed
# loading data 226 ...completed
# loading data 227 ...completed
# loading data 228 ...completed
# loading data 229 ...completed
# loading data 230 ...completed
# loading data 231 ...completed
# loading data 232 ...completed
# loading data 233 ...completed
# loading data 234 ...completed
# loading data 235 ...completed
# loading data 236 ...completed
# loading data 237 ...completed
# loading data 238 ...completed
# loading data 239 ...completed
# loading data 240 ...completed
# loading data 241 ...completed
# loading data 242 ...completed
# loading data 243 ...completed
# loading data 244 ...completed
# loading data 245 ...completed
# loading data 246 ...completed
# loading data 247 ...completed
# loading data 248 ...completed
# loading data 249 ...completed
# loading data 250 ...completed
# loading data 251 ...completed
# loading data 252 ...completed
# loading data 253 ...completed
# loading data 254 ...completed
# loading data 255 ...completed
# loading data 256 ...completed
# loading data 257 ...completed
# loading data 258 ...completed
# loading data 259 ...completed
# loading data 260 ...completed
# loading data 261 ...completed
# loading data 262 ...completed
# loading data 263 ...completed
# loading data 264 ...completed
# loading data 265 ...completed
# loading data 266 ...completed
# loading data 267 ...completed
# loading data 268 ...completed
# loading data 269 ...completed
# loading data 270 ...completed
# loading data 271 ...completed
# loading data 272 ...completed
# loading data 273 ...completed
# loading data 274 ...completed
# loading data 275 ...completed
# loading data 276 ...completed
# loading data 277 ...completed
# loading data 278 ...completed
# loading data 279 ...completed
# loading data 280 ...completed
# loading data 281 ...completed
# loading data 282 ...completed
# loading data 283 ...completed
# loading data 284 ...completed
# loading data 285 ...completed
# loading data 286 ...completed
# loading data 287 ...completed
# loading data 288 ...completed
# loading data 289 ...completed
# loading data 290 ...completed
# loading data 291 ...completed
# loading data 292 ...completed
# loading data 293 ...completed
# loading data 294 ...completed
# loading data 295 ...completed
# loading data 296 ...completed
# loading data 297 ...completed
# loading data 298 ...completed
# loading data 299 ...completed
# loading data 300 ...completed
# loading data 301 ...completed
# loading data 302 ...completed
# loading data 303 ...completed
# loading data 304 ...completed
# loading data 305 ...completed
# loading data 306 ...completed
# loading data 307 ...completed
# loading data 308 ...completed
# loading data 309 ...completed
# loading data 310 ...completed
# loading data 311 ...completed
# loading data 312 ...completed
# loading data 313 ...completed
# loading data 314 ...completed
# loading data 315 ...completed
# loading data 316 ...completed
# loading data 317 ...completed
# loading data 318 ...completed
# loading data 319 ...completed
# loading data 320 ...completed
# loading data 321 ...completed
# loading data 322 ...completed
# loading data 323 ...completed
# loading data 324 ...completed
# loading data 325 ...completed
# loading data 326 ...completed
# loading data 327 ...completed
# loading data 328 ...completed
# loading data 329 ...completed
# loading data 330 ...completed
# loading data 331 ...completed
# loading data 332 ...completed
# loading data 333 ...completed
# loading data 334 ...completed
# loading data 335 ...completed
# loading data 336 ...completed
# loading data 337 ...completed
# loading data 338 ...completed
# loading data 339 ...completed
# loading data 340 ...completed
# loading data 341 ...completed
# loading data 342 ...completed
# loading data 343 ...completed
# loading data 344 ...completed
# loading data 345 ...completed
# loading data 346 ...completed
# loading data 347 ...completed
# loading data 348 ...completed
# loading data 349 ...completed
# loading data 350 ...completed
# loading data 351 ...completed
# loading data 352 ...completed
# loading data 353 ...completed
# loading data 354 ...completed
# loading data 355 ...completed
# loading data 356 ...completed
# loading data 357 ...completed
# loading data 358 ...completed
# loading data 359 ...completed
# loading data 360 ...completed
# loading data 361 ...completed
# loading data 362 ...completed
# loading data 363 ...completed
# loading data 364 ...completed
# loading data 365 ...completed
# loading data 366 ...completed
# loading data 367 ...completed
# loading data 368 ...completed
# loading data 369 ...completed
# loading data 370 ...completed
# loading data 371 ...completed
# loading data 372 ...completed
# loading data 373 ...completed
# loading data 374 ...completed
# loading data 375 ...completed
# loading data 376 ...completed
# loading data 377 ...completed
# loading data 378 ...completed
# loading data 379 ...completed
# loading data 380 ...completed
# loading data 381 ...completed
# loading data 382 ...completed
# loading data 383 ...completed
# loading data 384 ...completed
# loading data 385 ...completed
# loading data 386 ...completed
# loading data 387 ...completed
# loading data 388 ...completed
# loading data 389 ...completed
# loading data 390 ...completed
# loading data 391 ...completed
# loading data 392 ...completed
# loading data 393 ...completed
# loading data 394 ...completed
# loading data 395 ...completed
# loading data 396 ...completed
# loading data 397 ...completed
# loading data 398 ...completed
# loading data 399 ...completed
# loading data 400 ...completed
# loading data 401 ...completed
# loading data 402 ...completed
# loading data 403 ...completed
# loading data 404 ...completed
# loading data 405 ...completed
# loading data 406 ...completed
# loading data 407 ...completed
# loading data 408 ...completed
# loading data 409 ...completed
# loading data 410 ...completed
# loading data 411 ...completed
# loading data 412 ...completed
# loading data 413 ...completed
# loading data 414 ...completed
# loading data 415 ...completed
# loading data 416 ...completed
# loading data 417 ...completed
# loading data 418 ...completed
# loading data 419 ...completed
# loading data 420 ...completed
# loading data 421 ...completed
# loading data 422 ...completed
# loading data 423 ...completed
# loading data 424 ...completed
# loading data 425 ...completed
# loading data 426 ...completed
# loading data 427 ...completed
# loading data 428 ...completed
# loading data 429 ...completed
# loading data 430 ...completed
# loading data 431 ...completed
# loading data 432 ...completed
# loading data 433 ...completed
# loading data 434 ...completed
# loading data 435 ...completed
# loading data 436 ...completed
# loading data 437 ...completed
# loading data 438 ...completed
# loading data 439 ...completed
# loading data 440 ...completed
# loading data 441 ...completed
# loading data 442 ...completed
# loading data 443 ...completed
# loading data 444 ...completed
# loading data 445 ...completed
# loading data 446 ...completed
# loading data 447 ...completed
# loading data 448 ...completed
# loading data 449 ...completed
# loading data 450 ...completed
# loading data 451 ...completed
# loading data 452 ...completed
# loading data 453 ...completed
# loading data 454 ...completed
# loading data 455 ...completed
# loading data 456 ...completed
# loading data 457 ...completed
# loading data 458 ...completed
# loading data 459 ...completed
# loading data 460 ...completed
# loading data 461 ...completed
# loading data 462 ...completed
# loading data 463 ...completed
# loading data 464 ...completed
# loading data 465 ...completed
# loading data 466 ...completed
# loading data 467 ...completed
# loading data 468 ...completed
# loading data 469 ...completed
# loading data 470 ...completed
# loading data 471 ...completed
# loading data 472 ...completed
# loading data 473 ...completed
# loading data 474 ...completed
# loading data 475 ...completed
# loading data 476 ...completed
# loading data 477 ...completed
# loading data 478 ...completed
# loading data 479 ...completed
# loading data 480 ...completed
# loading data 481 ...completed
# loading data 482 ...completed
# loading data 483 ...completed
# loading data 484 ...completed
# loading data 485 ...completed
# loading data 486 ...completed
# loading data 487 ...completed
# loading data 488 ...completed
# loading data 489 ...completed
# loading data 490 ...completed
# loading data 491 ...completed
# loading data 492 ...completed
# loading data 493 ...completed
# loading data 494 ...completed
# loading data 495 ...completed
# loading data 496 ...completed
# loading data 497 ...completed
# loading data 498 ...completed
# loading data 499 ...completed
# loading data 500 ...completed
# loading data 501 ...completed
# loading data 502 ...completed
# loading data 503 ...completed
# loading data 504 ...completed
# loading data 505 ...completed
# loading data 506 ...completed
# loading data 507 ...completed
# loading data 508 ...completed
# loading data 509 ...completed
# loading data 510 ...completed
# loading data 511 ...completed
# loading data 512 ...completed
# loading data 513 ...completed
# loading data 514 ...completed
# loading data 515 ...completed
# loading data 516 ...completed
# loading data 517 ...completed
# loading data 518 ...completed
# loading data 519 ...completed
# loading data 520 ...completed
# loading data 521 ...completed
# loading data 522 ...completed
# loading data 523 ...completed
# loading data 524 ...completed
# loading data 525 ...completed
# loading data 526 ...completed
# loading data 527 ...completed
# loading data 528 ...completed
# loading data 529 ...completed
# loading data 530 ...completed
# loading data 531 ...completed
# loading data 532 ...completed
# loading data 533 ...completed
# loading data 534 ...completed
# loading data 535 ...completed
# loading data 536 ...completed
# loading data 537 ...completed
# loading data 538 ...completed
# loading data 539 ...completed
# loading data 540 ...completed
# loading data 541 ...completed
# loading data 542 ...completed
# loading data 543 ...completed
# loading data 544 ...completed
# loading data 545 ...completed
# loading data 546 ...completed
# loading data 547 ...completed
# loading data 548 ...completed
# loading data 549 ...completed
# loading data 550 ...completed
# loading data 551 ...completed
# loading data 552 ...completed
# loading data 553 ...completed
# loading data 554 ...completed
# loading data 555 ...completed
# loading data 556 ...completed
# loading data 557 ...completed
# loading data 558 ...completed
# loading data 559 ...completed
# loading data 560 ...completed
# loading data 561 ...completed
# loading data 562 ...completed
# loading data 563 ...completed
# loading data 564 ...completed
# loading data 565 ...completed
# loading data 566 ...completed
# loading data 567 ...completed
# loading data 568 ...completed
# loading data 569 ...completed
# loading data 570 ...completed
# loading data 571 ...completed
# loading data 572 ...completed
# loading data 573 ...completed
# loading data 574 ...completed
# loading data 575 ...completed
# loading data 576 ...completed
# loading data 577 ...completed
# loading data 578 ...completed
# loading data 579 ...completed
# loading data 580 ...completed
# loading data 581 ...completed
# loading data 582 ...completed
# loading data 583 ...completed
# loading data 584 ...completed
# loading data 585 ...completed
# loading data 586 ...completed
# loading data 587 ...completed
# loading data 588 ...completed
# loading data 589 ...completed
# loading data 590 ...completed
# loading data 591 ...completed
# loading data 592 ...completed
# loading data 593 ...completed
# loading data 594 ...completed
# loading data 595 ...completed
# loading data 596 ...completed
# loading data 597 ...completed
# loading data 598 ...completed
# loading data 599 ...completed
# loading data 600 ...completed
# loading data 601 ...completed
# loading data 602 ...completed
# loading data 603 ...completed
# loading data 604 ...completed
# loading data 605 ...completed
# loading data 606 ...completed
# loading data 607 ...completed
# loading data 608 ...completed
# loading data 609 ...completed
# loading data 610 ...completed
# loading data 611 ...completed
# loading data 612 ...completed
# loading data 613 ...completed
# loading data 614 ...completed
# loading data 615 ...completed
# loading data 616 ...completed
# loading data 617 ...completed
# loading data 618 ...completed
# loading data 619 ...completed
# loading data 620 ...completed
# loading data 621 ...completed
# loading data 622 ...completed
# loading data 623 ...completed
# loading data 624 ...completed
# loading data 625 ...completed
# loading data 626 ...completed
# loading data 627 ...completed
# loading data 628 ...completed
# loading data 629 ...completed
# loading data 630 ...completed
# loading data 631 ...completed
# loading data 632 ...completed
# loading data 633 ...completed
# loading data 634 ...completed
# loading data 635 ...completed
# loading data 636 ...completed
# loading data 637 ...completed
# loading data 638 ...completed
# loading data 639 ...completed
# loading data 640 ...completed
# loading data 641 ...completed
# loading data 642 ...completed
# loading data 643 ...completed
# loading data 644 ...completed
# loading data 645 ...completed
# loading data 646 ...completed
# loading data 647 ...completed
# loading data 648 ...completed
# loading data 649 ...completed
# loading data 650 ...completed
# loading data 651 ...completed
# loading data 652 ...completed
# loading data 653 ...completed
# loading data 654 ...completed
# loading data 655 ...completed
# loading data 656 ...completed
# loading data 657 ...completed
# loading data 658 ...completed
# loading data 659 ...completed
# loading data 660 ...completed
# loading data 661 ...completed
# loading data 662 ...completed
# loading data 663 ...completed
# loading data 664 ...completed
# loading data 665 ...completed
# loading data 666 ...completed
# loading data 667 ...completed
# loading data 668 ...completed
# loading data 669 ...completed
# loading data 670 ...completed
# loading data 671 ...completed
# loading data 672 ...completed
# loading data 673 ...completed
# loading data 674 ...completed
# loading data 675 ...completed
# loading data 676 ...completed
# loading data 677 ...completed
# loading data 678 ...completed
# loading data 679 ...completed
# loading data 680 ...completed
# loading data 681 ...completed
# loading data 682 ...completed
# loading data 683 ...completed
# loading data 684 ...completed
# loading data 685 ...completed
# loading data 686 ...completed
# loading data 687 ...completed
# loading data 688 ...completed
# loading data 689 ...completed
# loading data 690 ...completed
# loading data 691 ...completed
# loading data 692 ...completed
# loading data 693 ...completed
# loading data 694 ...completed
# loading data 695 ...completed
# loading data 696 ...completed
# loading data 697 ...completed
# loading data 698 ...completed
# loading data 699 ...completed
# loading data 700 ...completed
# loading data 701 ...completed
# loading data 702 ...completed
# loading data 703 ...completed
# loading data 704 ...completed
# loading data 705 ...completed
# loading data 706 ...completed
# loading data 707 ...completed
# loading data 708 ...completed
# loading data 709 ...completed
# loading data 710 ...completed
# loading data 711 ...completed
# loading data 712 ...completed
# loading data 713 ...completed
# loading data 714 ...completed
# loading data 715 ...completed
# loading data 716 ...completed
# loading data 717 ...completed
# loading data 718 ...completed
# loading data 719 ...completed
# loading data 720 ...completed
# loading data 721 ...completed
# loading data 722 ...completed
# loading data 723 ...completed
# loading data 724 ...completed
# loading data 725 ...completed
# loading data 726 ...completed
# loading data 727 ...completed
# loading data 728 ...completed
# loading data 729 ...completed
# loading data 730 ...completed
# loading data 731 ...completed
# loading data 732 ...completed
# loading data 733 ...completed
# loading data 734 ...completed
# loading data 735 ...completed
# loading data 736 ...completed
# loading data 737 ...completed
# loading data 738 ...completed
# loading data 739 ...completed
# loading data 740 ...completed
# loading data 741 ...completed
# loading data 742 ...completed
# loading data 743 ...completed
# loading data 744 ...completed
# loading data 745 ...completed
# loading data 746 ...completed
# loading data 747 ...completed
# loading data 748 ...completed
# loading data 749 ...completed
# loading data 750 ...completed
# loading data 751 ...completed
# loading data 752 ...completed
# loading data 753 ...completed
# loading data 754 ...completed
# loading data 755 ...completed
# loading data 756 ...completed
# loading data 757 ...completed
# loading data 758 ...completed
# loading data 759 ...completed
# loading data 760 ...completed
# loading data 761 ...completed
# loading data 762 ...completed
# loading data 763 ...completed
# loading data 764 ...completed
# loading data 765 ...completed
# loading data 766 ...completed
# loading data 767 ...completed
# loading data 768 ...completed
# loading data 769 ...completed
# loading data 770 ...completed
# loading data 771 ...completed
# loading data 772 ...completed
# loading data 773 ...completed
# loading data 774 ...completed
# loading data 775 ...completed
# loading data 776 ...completed
# loading data 777 ...completed
# loading data 778 ...completed
# loading data 779 ...completed
# loading data 780 ...completed
# loading data 781 ...completed
# loading data 782 ...completed
# loading data 783 ...completed
# loading data 784 ...completed
# loading data 785 ...completed
# loading data 786 ...completed
# loading data 787 ...completed
# loading data 788 ...completed
# loading data 789 ...completed
# loading data 790 ...completed
# loading data 791 ...completed
# loading data 792 ...completed
# loading data 793 ...completed
# loading data 794 ...completed
# loading data 795 ...completed
# loading data 796 ...completed
# loading data 797 ...completed
# loading data 798 ...completed
# loading data 799 ...completed
# loading data 800 ...completed
# loading data 801 ...completed
# loading data 802 ...completed
# loading data 803 ...completed
# loading data 804 ...completed
# loading data 805 ...completed
# loading data 806 ...completed
# loading data 807 ...completed
# loading data 808 ...completed
# loading data 809 ...completed
# loading data 810 ...completed
# loading data 811 ...completed
# loading data 812 ...completed
# loading data 813 ...completed
# loading data 814 ...completed
# loading data 815 ...completed
# loading data 816 ...completed
# loading data 817 ...completed
# loading data 818 ...completed
# loading data 819 ...completed
# loading data 820 ...completed
# loading data 821 ...completed
# loading data 822 ...completed
# loading data 823 ...completed
# loading data 824 ...completed
# loading data 825 ...completed
# loading data 826 ...completed
# loading data 827 ...completed
# loading data 828 ...completed
# loading data 829 ...completed
# loading data 830 ...completed
# loading data 831 ...completed
# loading data 832 ...completed
# loading data 833 ...completed
# loading data 834 ...completed
# loading data 835 ...completed
# loading data 836 ...completed
# loading data 837 ...completed
# loading data 838 ...completed
# loading data 839 ...completed
# loading data 840 ...completed
# loading data 841 ...completed
# loading data 842 ...completed
# loading data 843 ...completed
# loading data 844 ...completed
# loading data 845 ...completed
# loading data 846 ...completed
# loading data 847 ...completed
# loading data 848 ...completed
# loading data 849 ...completed
# loading data 850 ...completed
# loading data 851 ...completed
# loading data 852 ...completed
# loading data 853 ...completed
# loading data 854 ...completed
# loading data 855 ...completed
# loading data 856 ...completed
# loading data 857 ...completed
# loading data 858 ...completed
# loading data 859 ...completed
# loading data 860 ...completed
# loading data 861 ...completed
# loading data 862 ...completed
# loading data 863 ...completed
# loading data 864 ...completed
# loading data 865 ...completed
# loading data 866 ...completed
# loading data 867 ...completed
# loading data 868 ...completed
# loading data 869 ...completed
# loading data 870 ...completed
# loading data 871 ...completed
# loading data 872 ...completed
# loading data 873 ...completed
# loading data 874 ...completed
# loading data 875 ...completed
# loading data 876 ...completed
# loading data 877 ...completed
# loading data 878 ...completed
# loading data 879 ...completed
# loading data 880 ...completed
# loading data 881 ...completed
# loading data 882 ...completed
# loading data 883 ...completed
# loading data 884 ...completed
# loading data 885 ...completed
# loading data 886 ...completed
# loading data 887 ...completed
# loading data 888 ...completed
# loading data 889 ...completed
# loading data 890 ...completed
# loading data 891 ...completed
# loading data 892 ...completed
# loading data 893 ...completed
# loading data 894 ...completed
# loading data 895 ...completed
# loading data 896 ...completed
# loading data 897 ...completed
# loading data 898 ...completed
# loading data 899 ...completed
# loading data 900 ...completed
# loading data 901 ...completed
# loading data 902 ...completed
# loading data 903 ...completed
# loading data 904 ...completed
# loading data 905 ...completed
# loading data 906 ...completed
# loading data 907 ...completed
# loading data 908 ...completed
# loading data 909 ...completed
# loading data 910 ...completed
# loading data 911 ...completed
# loading data 912 ...completed
# loading data 913 ...completed
# loading data 914 ...completed
# loading data 915 ...completed
# loading data 916 ...completed
# loading data 917 ...completed
# loading data 918 ...completed
# loading data 919 ...completed
# loading data 920 ...completed
# loading data 921 ...completed
# loading data 922 ...completed
# loading data 923 ...completed
# loading data 924 ...completed
# loading data 925 ...completed
# loading data 926 ...completed
# loading data 927 ...completed
# loading data 928 ...completed
# loading data 929 ...completed
# loading data 930 ...completed
# loading data 931 ...completed
# loading data 932 ...completed
# loading data 933 ...completed
# loading data 934 ...completed
# loading data 935 ...completed
# loading data 936 ...completed
# loading data 937 ...completed
# loading data 938 ...completed
# loading data 939 ...completed
# loading data 940 ...completed
# loading data 941 ...completed
# loading data 942 ...completed
# loading data 943 ...completed
# loading data 944 ...completed
# loading data 945 ...completed
# loading data 946 ...completed
# loading data 947 ...completed
# loading data 948 ...completed
# loading data 949 ...completed
# loading data 950 ...completed
# loading data 951 ...completed
# loading data 952 ...completed
# loading data 953 ...completed
# loading data 954 ...completed
# loading data 955 ...completed
# loading data 956 ...completed
# loading data 957 ...completed
# loading data 958 ...completed
# loading data 959 ...completed
# loading data 960 ...completed
# loading data 961 ...completed
# loading data 962 ...completed
# loading data 963 ...completed
# loading data 964 ...completed
# loading data 965 ...completed
# loading data 966 ...completed
# loading data 967 ...completed
# loading data 968 ...completed
# loading data 969 ...completed
# loading data 970 ...completed
# loading data 971 ...completed
# loading data 972 ...completed
# loading data 973 ...completed
# loading data 974 ...completed
# loading data 975 ...completed
# loading data 976 ...completed
# loading data 977 ...completed
# loading data 978 ...completed
# loading data 979 ...completed
# loading data 980 ...completed
# loading data 981 ...completed
# loading data 982 ...completed
# loading data 983 ...completed
# loading data 984 ...completed
# loading data 985 ...completed
# loading data 986 ...completed
# loading data 987 ...completed
# loading data 988 ...completed
# loading data 989 ...completed
# loading data 990 ...completed
# loading data 991 ...completed
# loading data 992 ...completed
# loading data 993 ...completed
# loading data 994 ...completed
# loading data 995 ...completed
# loading data 996 ...completed
# loading data 997 ...completed
# loading data 998 ...completed
# loading data 999 ...completed
# loading data 1000 ...completed
# loading data 1001 ...completed
# loading data 1002 ...completed
# loading data 1003 ...completed
# loading data 1004 ...completed
# loading data 1005 ...completed
# loading data 1006 ...completed
# loading data 1007 ...completed
# loading data 1008 ...completed
# loading data 1009 ...completed
# loading data 1010 ...completed
# loading data 1011 ...completed
# loading data 1012 ...completed
# loading data 1013 ...completed
# loading data 1014 ...completed
# loading data 1015 ...completed
# loading data 1016 ...completed
# loading data 1017 ...completed
# loading data 1018 ...completed
# loading data 1019 ...completed
# loading data 1020 ...completed
# loading data 1021 ...completed
# loading data 1022 ...completed
# loading data 1023 ...completed
# loading data 1024 ...completed
# loading data 1025 ...completed
# loading data 1026 ...completed
# loading data 1027 ...completed
# loading data 1028 ...completed
# loading data 1029 ...completed
# loading data 1030 ...completed
# loading data 1031 ...completed
# loading data 1032 ...completed
# loading data 1033 ...completed
# loading data 1034 ...completed
# loading data 1035 ...completed
# loading data 1036 ...completed
# loading data 1037 ...completed
# loading data 1038 ...completed
# loading data 1039 ...completed
# loading data 1040 ...completed
# loading data 1041 ...completed
# loading data 1042 ...completed
# loading data 1043 ...completed
# loading data 1044 ...completed
# loading data 1045 ...completed
# loading data 1046 ...completed
# loading data 1047 ...completed
# loading data 1048 ...completed
# loading data 1049 ...completed
# loading data 1050 ...completed
# loading data 1051 ...completed
# loading data 1052 ...completed
# loading data 1053 ...completed
# loading data 1054 ...completed
# loading data 1055 ...completed
# loading data 1056 ...completed
# loading data 1057 ...completed
# loading data 1058 ...completed
# loading data 1059 ...completed
# loading data 1060 ...completed
# loading data 1061 ...completed
# loading data 1062 ...completed
# loading data 1063 ...completed
# loading data 1064 ...completed
# loading data 1065 ...completed
# loading data 1066 ...completed
# loading data 1067 ...completed
# loading data 1068 ...completed
# loading data 1069 ...completed
# loading data 1070 ...completed
# loading data 1071 ...completed
# loading data 1072 ...completed
# loading data 1073 ...completed
# loading data 1074 ...completed
# loading data 1075 ...completed
# loading data 1076 ...completed
# loading data 1077 ...completed
# loading data 1078 ...completed
# loading data 1079 ...completed
# loading data 1080 ...completed
# loading data 1081 ...completed
# loading data 1082 ...completed
# loading data 1083 ...completed
# loading data 1084 ...completed
# loading data 1085 ...completed
# loading data 1086 ...completed
# loading data 1087 ...completed
# loading data 1088 ...completed
# loading data 1089 ...completed
# loading data 1090 ...completed
# loading data 1091 ...completed
# loading data 1092 ...completed
# loading data 1093 ...completed
# loading data 1094 ...completed
# loading data 1095 ...completed
# loading data 1096 ...completed
# loading data 1097 ...completed
# loading data 1098 ...completed
# loading data 1099 ...completed
# loading data 1100 ...completed
# loading data 1101 ...completed
# loading data 1102 ...completed
# loading data 1103 ...completed
# loading data 1104 ...completed
# loading data 1105 ...completed
# loading data 1106 ...completed
# loading data 1107 ...completed
# loading data 1108 ...completed
# loading data 1109 ...completed
# loading data 1110 ...completed
# loading data 1111 ...completed
# loading data 1112 ...completed
# loading data 1113 ...completed
# loading data 1114 ...completed
# loading data 1115 ...completed
# loading data 1116 ...completed
# loading data 1117 ...completed
# loading data 1118 ...completed
# loading data 1119 ...completed
# loading data 1120 ...completed
# loading data 1121 ...completed
# loading data 1122 ...completed
# loading data 1123 ...completed
# loading data 1124 ...completed
# loading data 1125 ...completed
# loading data 1126 ...completed
# loading data 1127 ...completed
# loading data 1128 ...completed
# loading data 1129 ...completed
# loading data 1130 ...completed
# loading data 1131 ...completed
# loading data 1132 ...completed
# loading data 1133 ...completed
# loading data 1134 ...completed
# loading data 1135 ...completed
# loading data 1136 ...completed
# loading data 1137 ...completed
# loading data 1138 ...completed
# loading data 1139 ...completed
# loading data 1140 ...completed
# loading data 1141 ...completed
# loading data 1142 ...completed
# loading data 1143 ...completed
# loading data 1144 ...completed
# loading data 1145 ...completed
# loading data 1146 ...completed
# loading data 1147 ...completed
# loading data 1148 ...completed
# loading data 1149 ...completed
# loading data 1150 ...completed
# loading data 1151 ...completed
# loading data 1152 ...completed
# loading data 1153 ...completed
# loading data 1154 ...completed
# loading data 1155 ...completed
# loading data 1156 ...completed
# loading data 1157 ...completed
# loading data 1158 ...completed
# loading data 1159 ...completed
# loading data 1160 ...completed
# loading data 1161 ...completed
# loading data 1162 ...completed
# loading data 1163 ...completed
# loading data 1164 ...completed
# loading data 1165 ...completed
# loading data 1166 ...completed
# loading data 1167 ...completed
# loading data 1168 ...completed
# loading data 1169 ...completed
# loading data 1170 ...completed
# loading data 1171 ...completed
# loading data 1172 ...completed
# loading data 1173 ...completed
# loading data 1174 ...completed
# loading data 1175 ...completed
# loading data 1176 ...completed
# loading data 1177 ...completed
# loading data 1178 ...completed
# loading data 1179 ...completed
# loading data 1180 ...completed
# loading data 1181 ...completed
# loading data 1182 ...completed
# loading data 1183 ...completed
# loading data 1184 ...completed
# loading data 1185 ...completed
# loading data 1186 ...completed
# loading data 1187 ...completed
# loading data 1188 ...completed
# loading data 1189 ...completed
# loading data 1190 ...completed
# loading data 1191 ...completed
# loading data 1192 ...completed
# loading data 1193 ...completed
# loading data 1194 ...completed
# loading data 1195 ...completed
# loading data 1196 ...completed
# loading data 1197 ...completed
# loading data 1198 ...completed
# loading data 1199 ...completed
# loading data 1200 ...completed
# loading data 1201 ...completed
# loading data 1202 ...completed
# loading data 1203 ...completed
# loading data 1204 ...completed
# loading data 1205 ...completed
# loading data 1206 ...completed
# loading data 1207 ...completed
# loading data 1208 ...completed
# loading data 1209 ...completed
# loading data 1210 ...completed
# loading data 1211 ...completed
# loading data 1212 ...completed
# loading data 1213 ...completed
# loading data 1214 ...completed
# loading data 1215 ...completed
# loading data 1216 ...completed
# loading data 1217 ...completed
# loading data 1218 ...completed
# loading data 1219 ...completed
# loading data 1220 ...completed
# loading data 1221 ...completed
# loading data 1222 ...completed
# loading data 1223 ...completed
# loading data 1224 ...completed
# loading data 1225 ...completed
# loading data 1226 ...completed
# loading data 1227 ...completed
# loading data 1228 ...completed
# loading data 1229 ...completed
# loading data 1230 ...completed
# loading data 1231 ...completed
# loading data 1232 ...completed
# loading data 1233 ...completed
# loading data 1234 ...completed
# loading data 1235 ...completed
# loading data 1236 ...completed
# loading data 1237 ...completed
# loading data 1238 ...completed
# loading data 1239 ...completed
# loading data 1240 ...completed
# loading data 1241 ...completed
# loading data 1242 ...completed
# loading data 1243 ...completed
# loading data 1244 ...completed
# loading data 1245 ...completed
# loading data 1246 ...completed
# loading data 1247 ...completed
# loading data 1248 ...completed
# loading data 1249 ...completed
# loading data 1250 ...completed
# loading data 1251 ...completed
# loading data 1252 ...completed
# loading data 1253 ...completed
# loading data 1254 ...completed
# loading data 1255 ...completed
# loading data 1256 ...completed
# loading data 1257 ...completed
# loading data 1258 ...completed
# loading data 1259 ...completed
# loading data 1260 ...completed
# loading data 1261 ...completed
# loading data 1262 ...completed
# loading data 1263 ...completed
# loading data 1264 ...completed
# loading data 1265 ...completed
# loading data 1266 ...completed
# loading data 1267 ...completed
# loading data 1268 ...completed
# loading data 1269 ...completed
# loading data 1270 ...completed
# loading data 1271 ...completed
# loading data 1272 ...completed
# loading data 1273 ...completed
# loading data 1274 ...completed
# loading data 1275 ...completed
# loading data 1276 ...completed
# loading data 1277 ...completed
# loading data 1278 ...completed
# loading data 1279 ...completed
# loading data 1280 ...completed
# loading data 1281 ...completed
# loading data 1282 ...completed
# loading data 1283 ...completed
# loading data 1284 ...completed
# loading data 1285 ...completed
# loading data 1286 ...completed
# loading data 1287 ...completed
# loading data 1288 ...completed
# loading data 1289 ...completed
# loading data 1290 ...completed
# loading data 1291 ...completed
# loading data 1292 ...completed
# loading data 1293 ...completed
# loading data 1294 ...completed
# loading data 1295 ...completed
# loading data 1296 ...completed
# loading data 1297 ...completed
# loading data 1298 ...completed
# loading data 1299 ...completed
# loading data 1300 ...completed
# loading data 1301 ...completed
# loading data 1302 ...completed
# loading data 1303 ...completed
# loading data 1304 ...completed
# loading data 1305 ...completed
# loading data 1306 ...completed
# loading data 1307 ...completed
# loading data 1308 ...completed
# loading data 1309 ...completed
# loading data 1310 ...completed
# loading data 1311 ...completed
# loading data 1312 ...completed
# loading data 1313 ...completed
# loading data 1314 ...completed
# loading data 1315 ...completed
# loading data 1316 ...completed
# loading data 1317 ...completed
# loading data 1318 ...completed
# loading data 1319 ...completed
# loading data 1320 ...completed
# loading data 1321 ...completed
# loading data 1322 ...completed
# loading data 1323 ...completed
# loading data 1324 ...completed
# loading data 1325 ...completed
# loading data 1326 ...completed
# loading data 1327 ...completed
# loading data 1328 ...completed
# loading data 1329 ...completed
# loading data 1330 ...completed
# loading data 1331 ...completed
# loading data 1332 ...completed
# loading data 1333 ...completed
# loading data 1334 ...completed
# loading data 1335 ...completed
# loading data 1336 ...completed
# loading data 1337 ...completed
# loading data 1338 ...completed
# loading data 1339 ...completed
# loading data 1340 ...completed
# loading data 1341 ...completed
# loading data 1342 ...completed
# loading data 1343 ...completed
# loading data 1344 ...completed
# loading data 1345 ...completed
# loading data 1346 ...completed
# loading data 1347 ...completed
# loading data 1348 ...completed
# loading data 1349 ...completed
# loading data 1350 ...completed
# loading data 1351 ...completed
# loading data 1352 ...completed
# loading data 1353 ...completed
# loading data 1354 ...completed
# loading data 1355 ...completed
# loading data 1356 ...completed
# loading data 1357 ...completed
# loading data 1358 ...completed
# loading data 1359 ...completed
# loading data 1360 ...completed
# loading data 1361 ...completed
# loading data 1362 ...completed
# loading data 1363 ...completed
# loading data 1364 ...completed
# loading data 1365 ...completed
# loading data 1366 ...completed
# loading data 1367 ...completed
# loading data 1368 ...completed
# loading data 1369 ...completed
# loading data 1370 ...completed
# loading data 1371 ...completed
# loading data 1372 ...completed
# loading data 1373 ...completed
# loading data 1374 ...completed
# loading data 1375 ...completed
# loading data 1376 ...completed
# loading data 1377 ...completed
# loading data 1378 ...completed
# loading data 1379 ...completed
# loading data 1380 ...completed
# loading data 1381 ...completed
# loading data 1382 ...completed
# loading data 1383 ...completed
# loading data 1384 ...completed
# loading data 1385 ...completed
# loading data 1386 ...completed
# loading data 1387 ...completed
# loading data 1388 ...completed
# loading data 1389 ...completed
# loading data 1390 ...completed
# loading data 1391 ...completed
# loading data 1392 ...completed
# loading data 1393 ...completed
# loading data 1394 ...completed
# loading data 1395 ...completed
# loading data 1396 ...completed
# loading data 1397 ...completed
# loading data 1398 ...completed
# loading data 1399 ...completed
# loading data 1400 ...completed
# loading data 1401 ...completed
# loading data 1402 ...completed
# loading data 1403 ...completed
# loading data 1404 ...completed
# loading data 1405 ...completed
# loading data 1406 ...completed
# loading data 1407 ...completed
# loading data 1408 ...completed
# loading data 1409 ...completed
# loading data 1410 ...completed
# loading data 1411 ...completed
# loading data 1412 ...completed
# loading data 1413 ...completed
# loading data 1414 ...completed
# loading data 1415 ...completed
# loading data 1416 ...completed
# loading data 1417 ...completed
# loading data 1418 ...completed
# loading data 1419 ...completed
# loading data 1420 ...completed
# loading data 1421 ...completed
# loading data 1422 ...completed
# loading data 1423 ...completed
# loading data 1424 ...completed
# loading data 1425 ...completed
# loading data 1426 ...completed
# loading data 1427 ...completed
# loading data 1428 ...completed
# loading data 1429 ...completed
# loading data 1430 ...completed
# loading data 1431 ...completed
# loading data 1432 ...completed
# loading data 1433 ...completed
# loading data 1434 ...completed
# loading data 1435 ...completed
# loading data 1436 ...completed
# loading data 1437 ...completed
# loading data 1438 ...completed
# loading data 1439 ...completed
# loading data 1440 ...completed
# loading data 1441 ...completed
# loading data 1442 ...completed
# loading data 1443 ...completed
# loading data 1444 ...completed
# loading data 1445 ...completed
# loading data 1446 ...completed
# loading data 1447 ...completed
# loading data 1448 ...completed
# loading data 1449 ...completed
# loading data 1450 ...completed
# loading data 1451 ...completed
# loading data 1452 ...completed
# loading data 1453 ...completed
# loading data 1454 ...completed
# loading data 1455 ...completed
# loading data 1456 ...completed
# loading data 1457 ...completed
# loading data 1458 ...completed
# loading data 1459 ...completed
# loading data 1460 ...completed
# loading data 1461 ...completed
# loading data 1462 ...completed
# loading data 1463 ...completed
# loading data 1464 ...completed
# loading data 1465 ...completed
# loading data 1466 ...completed
# loading data 1467 ...completed
# loading data 1468 ...completed
# loading data 1469 ...completed
# loading data 1470 ...completed
# loading data 1471 ...completed
# loading data 1472 ...completed
# loading data 1473 ...completed
# loading data 1474 ...completed
# loading data 1475 ...completed
# loading data 1476 ...completed
# loading data 1477 ...completed
# loading data 1478 ...completed
# loading data 1479 ...completed
# loading data 1480 ...completed
# loading data 1481 ...completed
# loading data 1482 ...completed
# loading data 1483 ...completed
# loading data 1484 ...completed
# loading data 1485 ...completed
# loading data 1486 ...completed
# loading data 1487 ...completed
# loading data 1488 ...completed
# loading data 1489 ...completed
# loading data 1490 ...completed
# loading data 1491 ...completed
# loading data 1492 ...completed
# loading data 1493 ...completed
# loading data 1494 ...completed
# loading data 1495 ...completed
# loading data 1496 ...completed
# loading data 1497 ...completed
# loading data 1498 ...completed
# loading data 1499 ...completed
# loading data 1500 ...completed
# loading data 1501 ...completed
# loading data 1502 ...completed
# loading data 1503 ...completed
# loading data 1504 ...completed
# loading data 1505 ...completed
# loading data 1506 ...completed
# loading data 1507 ...completed
# loading data 1508 ...completed
# loading data 1509 ...completed
# loading data 1510 ...completed
# loading data 1511 ...completed
# loading data 1512 ...completed
# loading data 1513 ...completed
# loading data 1514 ...completed
# loading data 1515 ...completed
# loading data 1516 ...completed
# loading data 1517 ...completed
# loading data 1518 ...completed
# loading data 1519 ...completed
# loading data 1520 ...completed
# loading data 1521 ...completed
# loading data 1522 ...completed
# loading data 1523 ...completed
# loading data 1524 ...completed
# loading data 1525 ...completed
# loading data 1526 ...completed
# loading data 1527 ...completed
# loading data 1528 ...completed
# loading data 1529 ...completed
# loading data 1530 ...completed
# loading data 1531 ...completed
# loading data 1532 ...completed
# loading data 1533 ...completed
# loading data 1534 ...completed
# loading data 1535 ...completed
# loading data 1536 ...completed
# loading data 1537 ...completed
# loading data 1538 ...completed
# loading data 1539 ...completed
# loading data 1540 ...completed
# loading data 1541 ...completed
# loading data 1542 ...completed
# loading data 1543 ...completed
# loading data 1544 ...completed
# loading data 1545 ...completed
# loading data 1546 ...completed
# loading data 1547 ...completed
# loading data 1548 ...completed
# loading data 1549 ...completed
# loading data 1550 ...completed
# loading data 1551 ...completed
# loading data 1552 ...completed
# loading data 1553 ...completed
# loading data 1554 ...completed
# loading data 1555 ...completed
# loading data 1556 ...completed
# loading data 1557 ...completed
# loading data 1558 ...completed
# loading data 1559 ...completed
# loading data 1560 ...completed
# loading data 1561 ...completed
# loading data 1562 ...completed
# loading data 1563 ...completed
# loading data 1564 ...completed
# loading data 1565 ...completed
# loading data 1566 ...completed
# loading data 1567 ...completed
# loading data 1568 ...completed
# loading data 1569 ...completed
# loading data 1570 ...completed
# loading data 1571 ...completed
# loading data 1572 ...completed
# loading data 1573 ...completed
# loading data 1574 ...completed
# loading data 1575 ...completed
# loading data 1576 ...completed
# loading data 1577 ...completed
# loading data 1578 ...completed
# loading data 1579 ...completed
# loading data 1580 ...completed
# loading data 1581 ...completed
# loading data 1582 ...completed
# loading data 1583 ...completed
# loading data 1584 ...completed
# ...
# loading data 7781 ...completed
# loading data 7782 ...completed
# loading data 7783 ...completed
# loading data 7784 ...completed
# loading data 7785 ...completed
# loading data 7786 ...completed
# loading data 7787 ...completed
# loading data 7788 ...completed
# loading data 7789 ...completed
# loading data 7790 ...completed
# loading data 7791 ...completed
# loading data 7792 ...completed
# loading data 7793 ...completed
# loading data 7794 ...completed
# loading data 7795 ...completed
# loading data 7796 ...completed
# loading data 7797 ...completed
# loading data 7798 ...completed
# loading data 7799 ...completed
# loading data 7800 ...completed
# loading data 7801 ...completed
# loading data 7802 ...completed
# loading data 7803 ...completed
# loading data 7804 ...completed
# loading data 7805 ...completed
# loading data 7806 ...completed
# loading data 7807 ...completed
# loading data 7808 ...completed
# loading data 7809 ...completed
# loading data 7810 ...completed
# loading data 7811 ...completed
# loading data 7812 ...completed
# loading data 7813 ...completed
# loading data 7814 ...completed
# loading data 7815 ...completed
# loading data 7816 ...completed
# loading data 7817 ...completed
# loading data 7818 ...completed
# loading data 7819 ...completed
# loading data 7820 ...completed
# loading data 7821 ...completed
# loading data 7822 ...completed
# loading data 7823 ...completed
# loading data 7824 ...completed
# loading data 7825 ...completed
# loading data 7826 ...completed
# loading data 7827 ...completed
# loading data 7828 ...completed
# loading data 7829 ...completed
# loading data 7830 ...completed
# loading data 7831 ...completed
# loading data 7832 ...completed
# loading data 7833 ...completed
# loading data 7834 ...completed
# loading data 7835 ...completed
# loading data 7836 ...completed
# loading data 7837 ...completed
# loading data 7838 ...completed
# loading data 7839 ...completed
# loading data 7840 ...completed
# loading data 7841 ...completed
# loading data 7842 ...completed
# loading data 7843 ...completed
# loading data 7844 ...completed
# loading data 7845 ...completed
# loading data 7846 ...completed
# loading data 7847 ...completed
# loading data 7848 ...completed
# loading data 7849 ...completed
# loading data 7850 ...completed
# loading data 7851 ...completed
# loading data 7852 ...completed
# loading data 7853 ...completed
# loading data 7854 ...completed
# loading data 7855 ...completed
# loading data 7856 ...completed
# loading data 7857 ...completed
# loading data 7858 ...completed
# loading data 7859 ...completed
# loading data 7860 ...completed
# loading data 7861 ...completed
# loading data 7862 ...completed
# loading data 7863 ...completed
# loading data 7864 ...completed
# loading data 7865 ...completed
# loading data 7866 ...completed
# loading data 7867 ...completed
# loading data 7868 ...completed
# loading data 7869 ...completed
# loading data 7870 ...completed
# loading data 7871 ...completed
# loading data 7872 ...completed
# loading data 7873 ...completed
# loading data 7874 ...completed
# loading data 7875 ...completed
# loading data 7876 ...completed
# loading data 7877 ...completed
# loading data 7878 ...completed
# loading data 7879 ...completed
# loading data 7880 ...completed
# loading data 7881 ...completed
# loading data 7882 ...completed
# loading data 7883 ...completed
# loading data 7884 ...completed
# loading data 7885 ...completed
# loading data 7886 ...completed
# loading data 7887 ...completed
# loading data 7888 ...completed
# loading data 7889 ...completed
# loading data 7890 ...completed
# loading data 7891 ...completed
# loading data 7892 ...completed
# loading data 7893 ...completed
# loading data 7894 ...completed
# loading data 7895 ...completed
# loading data 7896 ...completed
# loading data 7897 ...completed
# loading data 7898 ...completed
# loading data 7899 ...completed
# loading data 7900 ...completed
# loading data 7901 ...completed
# loading data 7902 ...completed
# loading data 7903 ...completed
# loading data 7904 ...completed
# loading data 7905 ...completed
# loading data 7906 ...completed
# loading data 7907 ...completed
# loading data 7908 ...completed
# loading data 7909 ...completed
# loading data 7910 ...completed
# loading data 7911 ...completed
# loading data 7912 ...completed
# loading data 7913 ...completed
# loading data 7914 ...completed
# loading data 7915 ...completed
# loading data 7916 ...completed
# loading data 7917 ...completed
# loading data 7918 ...completed
# loading data 7919 ...completed
# loading data 7920 ...completed
# loading data 7921 ...completed
# loading data 7922 ...completed
# loading data 7923 ...completed
# loading data 7924 ...completed
# loading data 7925 ...completed
# loading data 7926 ...completed
# loading data 7927 ...completed
# loading data 7928 ...completed
# loading data 7929 ...completed
# loading data 7930 ...completed
# loading data 7931 ...completed
# loading data 7932 ...completed
# loading data 7933 ...completed
# loading data 7934 ...completed
# loading data 7935 ...completed
# loading data 7936 ...completed
# loading data 7937 ...completed
# loading data 7938 ...completed
# loading data 7939 ...completed
# loading data 7940 ...completed
# loading data 7941 ...completed
# loading data 7942 ...completed
# loading data 7943 ...completed
# loading data 7944 ...completed
# loading data 7945 ...completed
# loading data 7946 ...completed
# loading data 7947 ...completed
# loading data 7948 ...completed
# loading data 7949 ...completed
# loading data 7950 ...completed
# loading data 7951 ...completed
# loading data 7952 ...completed
# loading data 7953 ...completed
# loading data 7954 ...completed
# loading data 7955 ...completed
# loading data 7956 ...completed
# loading data 7957 ...completed
# loading data 7958 ...completed
# loading data 7959 ...completed
# loading data 7960 ...completed
# loading data 7961 ...completed
# loading data 7962 ...completed
# loading data 7963 ...completed
# loading data 7964 ...completed
# loading data 7965 ...completed
# loading data 7966 ...completed
# loading data 7967 ...completed
# loading data 7968 ...completed
# loading data 7969 ...completed
# loading data 7970 ...completed
# loading data 7971 ...completed
# loading data 7972 ...completed
# loading data 7973 ...completed
# loading data 7974 ...completed
# loading data 7975 ...completed
# loading data 7976 ...completed
# loading data 7977 ...completed
# loading data 7978 ...completed
# loading data 7979 ...completed
# loading data 7980 ...completed
# loading data 7981 ...completed
# loading data 7982 ...completed
# loading data 7983 ...completed
# loading data 7984 ...completed
# loading data 7985 ...completed
# loading data 7986 ...completed
# loading data 7987 ...completed
# loading data 7988 ...completed
# loading data 7989 ...completed
# loading data 7990 ...completed
# loading data 7991 ...completed
# loading data 7992 ...completed
# loading data 7993 ...completed
# loading data 7994 ...completed
# loading data 7995 ...completed
# loading data 7996 ...completed
# loading data 7997 ...completed
# loading data 7998 ...completed
# loading data 7999 ...completed
# loading data 8000 ...completed
# loading data 8001 ...completed
# loading data 8002 ...completed
# loading data 8003 ...completed
# loading data 8004 ...completed
# loading data 8005 ...completed
# loading data 8006 ...completed
# loading data 8007 ...completed
# loading data 8008 ...completed
# loading data 8009 ...completed
# loading data 8010 ...completed
# loading data 8011 ...completed
# loading data 8012 ...completed
# loading data 8013 ...completed
# loading data 8014 ...completed
# loading data 8015 ...completed
# loading data 8016 ...completed
# loading data 8017 ...completed
# loading data 8018 ...completed
# loading data 8019 ...completed
# loading data 8020 ...completed
# loading data 8021 ...completed
# loading data 8022 ...completed
# loading data 8023 ...completed
# loading data 8024 ...completed
# loading data 8025 ...completed
# loading data 8026 ...completed
# loading data 8027 ...completed
# loading data 8028 ...completed
# loading data 8029 ...completed
# loading data 8030 ...completed
# loading data 8031 ...completed
# loading data 8032 ...completed
# loading data 8033 ...completed
# loading data 8034 ...completed
# loading data 8035 ...completed
# loading data 8036 ...completed
# loading data 8037 ...completed
# loading data 8038 ...completed
# loading data 8039 ...completed
# loading data 8040 ...completed
# loading data 8041 ...completed
# loading data 8042 ...completed
# loading data 8043 ...completed
# loading data 8044 ...completed
# loading data 8045 ...completed
# loading data 8046 ...completed
# loading data 8047 ...completed
# loading data 8048 ...completed
# loading data 8049 ...completed
# loading data 8050 ...completed
# loading data 8051 ...completed
# loading data 8052 ...completed
# loading data 8053 ...completed
# loading data 8054 ...completed
# loading data 8055 ...completed
# loading data 8056 ...completed
# loading data 8057 ...completed
# loading data 8058 ...completed
# loading data 8059 ...completed
# loading data 8060 ...completed
# loading data 8061 ...completed
# loading data 8062 ...completed
# loading data 8063 ...completed
# loading data 8064 ...completed
# loading data 8065 ...completed
# loading data 8066 ...completed
# loading data 8067 ...completed
# loading data 8068 ...completed
# loading data 8069 ...completed
# loading data 8070 ...completed
# loading data 8071 ...completed
# loading data 8072 ...completed
# loading data 8073 ...completed
# loading data 8074 ...completed
# loading data 8075 ...completed
# loading data 8076 ...completed
# loading data 8077 ...completed
# loading data 8078 ...completed
# loading data 8079 ...completed
# loading data 8080 ...completed
# loading data 8081 ...completed
# loading data 8082 ...completed
# loading data 8083 ...completed
# loading data 8084 ...completed
# loading data 8085 ...completed
# loading data 8086 ...completed
# loading data 8087 ...completed
# loading data 8088 ...completed
# loading data 8089 ...completed
# loading data 8090 ...completed
# loading data 8091 ...completed
# loading data 8092 ...completed
# loading data 8093 ...completed
# loading data 8094 ...completed
# loading data 8095 ...completed
# loading data 8096 ...completed
# loading data 8097 ...completed
# loading data 8098 ...completed
# loading data 8099 ...completed
# loading data 8100 ...completed
# loading data 8101 ...completed
# loading data 8102 ...completed
# loading data 8103 ...completed
# loading data 8104 ...completed
# loading data 8105 ...completed
# loading data 8106 ...completed
# loading data 8107 ...completed
# loading data 8108 ...completed
# loading data 8109 ...completed
# loading data 8110 ...completed
# loading data 8111 ...completed
# loading data 8112 ...completed
# loading data 8113 ...completed
# loading data 8114 ...completed
# loading data 8115 ...completed
# loading data 8116 ...completed
# loading data 8117 ...completed
# loading data 8118 ...completed
# loading data 8119 ...completed
# loading data 8120 ...completed
# loading data 8121 ...completed
# loading data 8122 ...completed
# loading data 8123 ...completed
# loading data 8124 ...completed
# loading data 8125 ...completed
# loading data 8126 ...completed
# loading data 8127 ...completed
# loading data 8128 ...completed
# loading data 8129 ...completed
# loading data 8130 ...completed
# loading data 8131 ...completed
# loading data 8132 ...completed
# loading data 8133 ...completed
# loading data 8134 ...completed
# loading data 8135 ...completed
# loading data 8136 ...completed
# loading data 8137 ...completed
# loading data 8138 ...completed
# loading data 8139 ...completed
# loading data 8140 ...completed
# loading data 8141 ...completed
# loading data 8142 ...completed
# loading data 8143 ...completed
# loading data 8144 ...completed
# loading data 8145 ...completed
# loading data 8146 ...completed
# loading data 8147 ...completed
# loading data 8148 ...completed
# loading data 8149 ...completed
# loading data 8150 ...completed
# loading data 8151 ...completed
# loading data 8152 ...completed
# loading data 8153 ...completed
# loading data 8154 ...completed
# loading data 8155 ...completed
# loading data 8156 ...completed
# loading data 8157 ...completed
# loading data 8158 ...completed
# loading data 8159 ...completed
# loading data 8160 ...completed
# loading data 8161 ...completed
# loading data 8162 ...completed
# loading data 8163 ...completed
# loading data 8164 ...completed
# loading data 8165 ...completed
# loading data 8166 ...completed
# loading data 8167 ...completed
# loading data 8168 ...completed
# loading data 8169 ...completed
# loading data 8170 ...completed
# loading data 8171 ...completed
# loading data 8172 ...completed
# loading data 8173 ...completed
# loading data 8174 ...completed
# loading data 8175 ...completed
# loading data 8176 ...completed
# loading data 8177 ...completed
# loading data 8178 ...completed
# loading data 8179 ...completed
# loading data 8180 ...completed
# loading data 8181 ...completed
# loading data 8182 ...completed
# loading data 8183 ...completed
# loading data 8184 ...completed
# loading data 8185 ...completed
# loading data 8186 ...completed
# loading data 8187 ...completed
# loading data 8188 ...completed
# loading data 8189 ...completed
# loading data 8190 ...completed
# loading data 8191 ...completed
# loading data 8192 ...completed
# loading data 8193 ...completed
# loading data 8194 ...completed
# loading data 8195 ...completed
# loading data 8196 ...completed
# loading data 8197 ...completed
# loading data 8198 ...completed
# loading data 8199 ...completed
# loading data 8200 ...completed
# loading data 8201 ...completed
# loading data 8202 ...completed
# loading data 8203 ...completed
# loading data 8204 ...completed
# loading data 8205 ...completed
# loading data 8206 ...completed
# loading data 8207 ...completed
# loading data 8208 ...completed
# loading data 8209 ...completed
# loading data 8210 ...completed
# loading data 8211 ...completed
# loading data 8212 ...completed
# loading data 8213 ...completed
# loading data 8214 ...completed
# loading data 8215 ...completed
# loading data 8216 ...completed
# loading data 8217 ...completed
# loading data 8218 ...completed
# loading data 8219 ...completed
# loading data 8220 ...completed
# loading data 8221 ...completed
# loading data 8222 ...completed
# loading data 8223 ...completed
# loading data 8224 ...completed
# loading data 8225 ...completed
# loading data 8226 ...completed
# loading data 8227 ...completed
# loading data 8228 ...completed
# loading data 8229 ...completed
# loading data 8230 ...completed
# loading data 8231 ...completed
# loading data 8232 ...completed
# loading data 8233 ...completed
# loading data 8234 ...completed
# loading data 8235 ...completed
# loading data 8236 ...completed
# loading data 8237 ...completed
# loading data 8238 ...completed
# loading data 8239 ...completed
# loading data 8240 ...completed
# loading data 8241 ...completed
# loading data 8242 ...completed
# loading data 8243 ...completed
# loading data 8244 ...completed
# loading data 8245 ...completed
# loading data 8246 ...completed
# loading data 8247 ...completed
# loading data 8248 ...completed
# loading data 8249 ...completed
# loading data 8250 ...completed
# loading data 8251 ...completed
# loading data 8252 ...completed
# loading data 8253 ...completed
# loading data 8254 ...completed
# loading data 8255 ...completed
# loading data 8256 ...completed
# loading data 8257 ...completed
# loading data 8258 ...completed
# loading data 8259 ...completed
# loading data 8260 ...completed
# loading data 8261 ...completed
# loading data 8262 ...completed
# loading data 8263 ...completed
# loading data 8264 ...completed
# loading data 8265 ...completed
# loading data 8266 ...completed
# loading data 8267 ...completed
# loading data 8268 ...completed
# loading data 8269 ...completed
# loading data 8270 ...completed
# loading data 8271 ...completed
# loading data 8272 ...completed
# loading data 8273 ...completed
# loading data 8274 ...completed
# loading data 8275 ...completed
# loading data 8276 ...completed
# loading data 8277 ...completed
# loading data 8278 ...completed
# loading data 8279 ...completed
# loading data 8280 ...completed
# loading data 8281 ...completed
# loading data 8282 ...completed
# loading data 8283 ...completed
# loading data 8284 ...completed
# loading data 8285 ...completed
# loading data 8286 ...completed
# loading data 8287 ...completed
# loading data 8288 ...completed
# loading data 8289 ...completed
# loading data 8290 ...completed
# loading data 8291 ...completed
# loading data 8292 ...completed
# loading data 8293 ...completed
# loading data 8294 ...completed
# loading data 8295 ...completed
# saving...done

# %% [markdown]
# ## Saving x, y

# %%
# ECG와 PPG input 합치기
x_total = []
for i in range(len(x_total_ppg)):
    x_total.append(x_total_ppg[i]+x_total_ecg[i])

# np.array로 변환  
x_total = np.array(x_total, np.float32)

#NRS score가 4 이하면 0, 4 이상이면 1 (severe pain)
y_total_bin = np.where(y_total < 4, 0, 1)

# 총 dataset의 크기
print('size of x_total:', len(x_total))
print('size of y_total:', len(y_total))

# 저장하기
#np.savez_compressed('x_total.npz', x_total)
#np.savez_compressed('y_total.npz', y_total)
# Out:
# size of x_total: 153328
# size of y_total: 153328

# %%
len_list = []
for x_ele in x_total:
    len_list.append(len(x_ele))
    
from collections import Counter
len_hist = Counter(len_list)
len_hist
# Out:
# Counter({1001: 156079,
#          667: 2,
#          167: 2,
#          857: 2,
#          357: 2,
#          704: 1,
#          204: 1,
#          267: 1,
#          305: 2,
#          756: 1,
#          256: 1,
#          426: 1,
#          748: 2,
#          668: 1,
#          168: 1,
#          910: 1,
#          410: 1,
#          778: 2,
#          664: 1,
#          599: 2,
#          979: 1,
#          821: 1,
#          321: 2,
#          890: 1,
#          390: 1,
#          894: 1,
#          394: 1,
#          828: 1,
#          328: 1,
#          752: 1,
#          252: 1,
#          612: 2,
#          309: 2,
#          724: 1,
#          224: 1,
#          626: 1,
#          824: 1,
#          324: 1,
#          255: 1,
#          691: 1,
#          191: 1,
#          395: 1,
#          698: 2,
#          278: 1,
#          859: 1,
#          359: 1,
#          470: 1,
#          786: 1,
#          286: 1,
#          630: 1,
#          848: 3,
#          348: 3,
#          808: 1,
#          308: 1,
#          572: 1,
#          226: 1,
#          527: 1,
#          621: 1,
#          508: 1,
#          866: 2,
#          366: 2,
#          210: 1,
#          837: 2,
#          337: 2,
#          639: 1,
#          139: 1,
#          809: 1,
#          783: 1,
#          283: 1,
#          277: 2,
#          811: 1,
#          466: 1,
#          733: 1,
#          233: 1,
#          842: 1,
#          342: 1,
#          973: 1,
#          473: 1,
#          649: 1,
#          517: 1,
#          988: 1,
#          488: 2,
#          653: 2,
#          153: 1,
#          574: 1,
#          772: 1,
#          272: 1,
#          847: 1,
#          347: 1,
#          785: 2,
#          285: 2,
#          898: 2,
#          398: 1,
#          749: 1,
#          249: 1,
#          568: 1,
#          826: 2,
#          326: 2,
#          674: 1,
#          174: 1,
#          530: 1,
#          906: 1,
#          636: 1,
#          136: 1,
#          853: 2,
#          353: 2,
#          734: 2,
#          234: 2,
#          904: 1,
#          404: 1,
#          580: 3,
#          183: 1,
#          758: 1,
#          258: 1,
#          757: 1,
#          257: 1,
#          198: 1,
#          909: 1,
#          409: 1,
#          354: 1,
#          944: 1,
#          444: 1,
#          686: 2,
#          186: 2,
#          261: 1,
#          514: 1,
#          802: 1,
#          302: 1,
#          561: 1,
#          647: 1,
#          611: 1,
#          690: 1,
#          190: 1,
#          610: 1,
#          781: 1,
#          281: 1,
#          805: 1,
#          889: 1,
#          389: 1,
#          969: 1,
#          469: 1,
#          762: 1,
#          262: 1,
#          917: 1,
#          565: 1,
#          929: 1,
#          429: 1,
#          562: 1,
#          926: 1,
#          587: 1,
#          510: 1,
#          675: 2,
#          175: 1,
#          684: 1,
#          184: 2,
#          863: 1,
#          363: 1,
#          268: 1,
#          696: 1,
#          149: 1,
#          939: 1,
#          439: 1,
#          540: 1,
#          615: 1,
#          908: 2,
#          408: 1,
#          241: 1,
#          777: 1,
#          806: 1,
#          306: 1,
#          634: 1,
#          714: 1,
#          214: 1,
#          596: 1,
#          893: 1,
#          393: 1,
#          796: 1,
#          730: 1,
#          230: 1,
#          964: 1,
#          464: 1,
#          549: 1,
#          542: 1,
#          584: 1,
#          882: 1,
#          382: 1,
#          364: 1,
#          739: 1,
#          239: 1,
#          907: 1,
#          407: 1,
#          633: 1,
#          862: 1,
#          362: 1,
#          507: 1,
#          459: 1,
#          899: 1,
#          399: 1})

# %%
cache_path = 'cache/x_y_total_set'
if os.path.exists('cache/x_y_total_set'):
    print('loading...', flush=True)
    x_total, y_total = pickle.load(open('cache/x_y_total_set', 'rb'))
    print('loading completed', flush=True)
else:
    print('saving...', flush=True)
    pickle.dump((x_total, y_total), open('cache/x_y_total_set','wb'))
    print('saving completed', flush=True)

# %% [markdown]
# ## Splitting into train, test set

# %%
from sklearn.model_selection import train_test_split

# test set 로딩
if os.path.exists('x_test.npz'):
    print('loading test...', flush=True, end='')
    x_test = np.load('x_test.npz', allow_pickle=True)['arr_0']
    y_test = np.load('y_test.npz')['arr_0']
    
    x_train = np.load('x_train.npz', allow_pickle=True)['arr_0']
    y_train = np.load('y_train.npz')['arr_0']
    print('done', flush=True)
else:
    #training set과 test set으로 나누기
    x_train, x_test, y_train, y_test = train_test_split(x_total, y_total, test_size = 0.1, shuffle=True)
    print('saving...', flush=True, end='')
    np.savez_compressed('x_test.npz', x_test)
    np.savez_compressed('y_test.npz', y_test)

    np.savez_compressed('x_train.npz', x_train)
    np.savez_compressed('y_train.npz', y_train)
    print('done', flush=True)
# Out:
# saving...done

# %% [markdown]
# ## 1D-CNN model using Keras

# %%
# binary classification
y_train = np.where(y_train < 4, 0, 1)
y_test = np.where(y_test < 4, 0, 1)

# %%
BATCH_SIZE = 512

# nan 을 이전 값으로 채움
x_train = pd.DataFrame(x_train).fillna(method='ffill', axis=1).fillna(method='bfill', axis=1).values
x_test = pd.DataFrame(x_test).fillna(method='ffill', axis=1).fillna(method='bfill', axis=1).values

# CNN에 입력으로 넣기 위해 차원을 추가
x_train = x_train[..., None]
x_test = x_test[..., None]

print('train {} ({} events {:.1f}%), test {}'.format(len(y_train), sum(y_train), 100*np.mean(y_train), len(x_test)))
# Out:
# train 137995 (106653 events 77.3%), test 15333

# %%
from keras.models import Sequential
from keras.models import Model, load_model
from keras.layers import Dense, Conv1D, MaxPooling1D, GlobalMaxPool1D, BatchNormalization, Dropout
from keras.callbacks import ModelCheckpoint, EarlyStopping
from sklearn.metrics import auc, classification_report, confusion_matrix, accuracy_score, roc_curve, roc_auc_score, f1_score, precision_recall_curve
import tensorflow as tf

num_nodes = [64, 64, 64, 64, 64, 64]

testname = '-'.join([str(num_node) for num_node in num_nodes])
print(testname)

# 출력 폴더를 생성
odir = "output"
if not os.path.exists(odir):
    os.mkdir(odir)
weight_path = odir + "/weights.hdf5"

# build a model
model = Sequential()
for num_node in num_nodes:
    model.add(Conv1D(filters=num_node, kernel_size=3, padding='valid'))
    model.add(BatchNormalization())
    model.add(MaxPooling1D())
model.add(GlobalMaxPool1D())
model.add(Dense(16, activation='sigmoid'))
model.add(Dropout(0.2))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy', tf.keras.metrics.AUC()])
hist = model.fit(x_train, y_train, validation_split=0.1, epochs=100, batch_size=BATCH_SIZE, class_weight={0:1, 1:10}, 
                        callbacks=[ModelCheckpoint(monitor='val_loss', filepath=weight_path, verbose=1, save_best_only=True)])
                                    #EarlyStopping(monitor='val_loss', patience=7, verbose=0, mode='auto')])

# 모델을 저장
open(odir + "/model.json", "wt").write(model.to_json())

model.load_weights(weight_path)

# 전체 test 샘플을 한번에 예측
y_pred = model.predict(x_test).flatten()

# 결과를 저장
np.savetxt('pred_y.txt', y_pred)
# Out:
# 64-64-64-64-64-64
# Epoch 1/100
# 243/243 [==============================] - ETA: 0s - loss: 1.2591 - accuracy: 0.7718 - auc_8: 0.5004
# Epoch 00001: val_loss improved from inf to 0.76839, saving model to output/weights.hdf5
# 243/243 [==============================] - 76s 314ms/step - loss: 1.2591 - accuracy: 0.7718 - auc_8: 0.5004 - val_loss: 0.7684 - val_accuracy: 0.7771 - val_auc_8: 0.5365
# Epoch 2/100
# 243/243 [==============================] - ETA: 0s - loss: 1.0853 - accuracy: 0.7724 - auc_8: 0.5053
# Epoch 00002: val_loss did not improve from 0.76839
# 243/243 [==============================] - 74s 305ms/step - loss: 1.0853 - accuracy: 0.7724 - auc_8: 0.5053 - val_loss: 0.8287 - val_accuracy: 0.7771 - val_auc_8: 0.5116
# Epoch 3/100
# 243/243 [==============================] - ETA: 0s - loss: 1.0768 - accuracy: 0.7724 - auc_8: 0.5204
# Epoch 00003: val_loss did not improve from 0.76839
# 243/243 [==============================] - 74s 304ms/step - loss: 1.0768 - accuracy: 0.7724 - auc_8: 0.5204 - val_loss: 0.8492 - val_accuracy: 0.7771 - val_auc_8: 0.5402
# Epoch 4/100
# 243/243 [==============================] - ETA: 0s - loss: 1.0707 - accuracy: 0.7724 - auc_8: 0.5324
# Epoch 00004: val_loss did not improve from 0.76839
# 243/243 [==============================] - 74s 304ms/step - loss: 1.0707 - accuracy: 0.7724 - auc_8: 0.5324 - val_loss: 0.8421 - val_accuracy: 0.7771 - val_auc_8: 0.5741
# Epoch 5/100
# 243/243 [==============================] - ETA: 0s - loss: 1.0641 - accuracy: 0.7724 - auc_8: 0.5439
# Epoch 00005: val_loss did not improve from 0.76839
# 243/243 [==============================] - 74s 305ms/step - loss: 1.0641 - accuracy: 0.7724 - auc_8: 0.5439 - val_loss: 0.8317 - val_accuracy: 0.7771 - val_auc_8: 0.5887
# Epoch 6/100
# 243/243 [==============================] - ETA: 0s - loss: 1.0630 - accuracy: 0.7724 - auc_8: 0.5467
# Epoch 00006: val_loss did not improve from 0.76839
# 243/243 [==============================] - 73s 301ms/step - loss: 1.0630 - accuracy: 0.7724 - auc_8: 0.5467 - val_loss: 0.8406 - val_accuracy: 0.7771 - val_auc_8: 0.5802
# Epoch 7/100
# 243/243 [==============================] - ETA: 0s - loss: 1.0591 - accuracy: 0.7724 - auc_8: 0.5540
# Epoch 00007: val_loss did not improve from 0.76839
# 243/243 [==============================] - 73s 301ms/step - loss: 1.0591 - accuracy: 0.7724 - auc_8: 0.5540 - val_loss: 0.8202 - val_accuracy: 0.7771 - val_auc_8: 0.5893
# Epoch 8/100
# 243/243 [==============================] - ETA: 0s - loss: 1.0557 - accuracy: 0.7724 - auc_8: 0.5602
# Epoch 00008: val_loss did not improve from 0.76839
# 243/243 [==============================] - 73s 300ms/step - loss: 1.0557 - accuracy: 0.7724 - auc_8: 0.5602 - val_loss: 0.8782 - val_accuracy: 0.7771 - val_auc_8: 0.5775
# Epoch 9/100
# 243/243 [==============================] - ETA: 0s - loss: 1.0540 - accuracy: 0.7724 - auc_8: 0.5634
# Epoch 00009: val_loss did not improve from 0.76839
# 243/243 [==============================] - 73s 301ms/step - loss: 1.0540 - accuracy: 0.7724 - auc_8: 0.5634 - val_loss: 0.8067 - val_accuracy: 0.7771 - val_auc_8: 0.6076
# Epoch 10/100
# 243/243 [==============================] - ETA: 0s - loss: 1.0473 - accuracy: 0.7724 - auc_8: 0.5741
# Epoch 00010: val_loss improved from 0.76839 to 0.74155, saving model to output/weights.hdf5
# 243/243 [==============================] - 72s 298ms/step - loss: 1.0473 - accuracy: 0.7724 - auc_8: 0.5741 - val_loss: 0.7415 - val_accuracy: 0.7771 - val_auc_8: 0.6143
# Epoch 11/100
# 243/243 [==============================] - ETA: 0s - loss: 1.0438 - accuracy: 0.7724 - auc_8: 0.5797
# Epoch 00011: val_loss did not improve from 0.74155
# 243/243 [==============================] - 72s 298ms/step - loss: 1.0438 - accuracy: 0.7724 - auc_8: 0.5797 - val_loss: 0.8606 - val_accuracy: 0.7771 - val_auc_8: 0.6090
# Epoch 12/100
# 243/243 [==============================] - ETA: 0s - loss: 1.0386 - accuracy: 0.7724 - auc_8: 0.5874
# Epoch 00012: val_loss did not improve from 0.74155
# 243/243 [==============================] - 72s 298ms/step - loss: 1.0386 - accuracy: 0.7724 - auc_8: 0.5874 - val_loss: 0.8322 - val_accuracy: 0.7771 - val_auc_8: 0.6112
# Epoch 13/100
# 243/243 [==============================] - ETA: 0s - loss: 1.0318 - accuracy: 0.7724 - auc_8: 0.5974
# Epoch 00013: val_loss did not improve from 0.74155
# 243/243 [==============================] - 72s 297ms/step - loss: 1.0318 - accuracy: 0.7724 - auc_8: 0.5974 - val_loss: 0.8807 - val_accuracy: 0.7771 - val_auc_8: 0.6196
# Epoch 14/100
# 243/243 [==============================] - ETA: 0s - loss: 1.0271 - accuracy: 0.7724 - auc_8: 0.6037
# Epoch 00014: val_loss improved from 0.74155 to 0.68111, saving model to output/weights.hdf5
# 243/243 [==============================] - 72s 298ms/step - loss: 1.0271 - accuracy: 0.7724 - auc_8: 0.6037 - val_loss: 0.6811 - val_accuracy: 0.7771 - val_auc_8: 0.6084
# Epoch 15/100
# 243/243 [==============================] - ETA: 0s - loss: 1.0242 - accuracy: 0.7724 - auc_8: 0.6098
# Epoch 00015: val_loss did not improve from 0.68111
# 243/243 [==============================] - 72s 297ms/step - loss: 1.0242 - accuracy: 0.7724 - auc_8: 0.6098 - val_loss: 0.7947 - val_accuracy: 0.7771 - val_auc_8: 0.6056
# Epoch 16/100
# 243/243 [==============================] - ETA: 0s - loss: 1.0185 - accuracy: 0.7724 - auc_8: 0.6193
# Epoch 00016: val_loss did not improve from 0.68111
# 243/243 [==============================] - 73s 300ms/step - loss: 1.0185 - accuracy: 0.7724 - auc_8: 0.6193 - val_loss: 0.7870 - val_accuracy: 0.7771 - val_auc_8: 0.6339
# Epoch 17/100
# 243/243 [==============================] - ETA: 0s - loss: 1.0139 - accuracy: 0.7724 - auc_8: 0.6275
# Epoch 00017: val_loss did not improve from 0.68111
# 243/243 [==============================] - 74s 304ms/step - loss: 1.0139 - accuracy: 0.7724 - auc_8: 0.6275 - val_loss: 0.7843 - val_accuracy: 0.7771 - val_auc_8: 0.6379
# Epoch 18/100
# 243/243 [==============================] - ETA: 0s - loss: 1.0110 - accuracy: 0.7724 - auc_8: 0.6331
# Epoch 00018: val_loss did not improve from 0.68111
# 243/243 [==============================] - 73s 300ms/step - loss: 1.0110 - accuracy: 0.7724 - auc_8: 0.6331 - val_loss: 0.8056 - val_accuracy: 0.7772 - val_auc_8: 0.6372
# Epoch 19/100
# 176/243 [====================>.........] - ETA: 19s - loss: 1.0042 - accuracy: 0.7727 - auc_8: 0.6441
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-103-b84555a425d5> in <module>
#      30 model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy', tf.keras.metrics.AUC()])
#      31 hist = model.fit(x_train, y_train, validation_split=0.1, epochs=100, batch_size=BATCH_SIZE, class_weight={0:1, 1:10},
# ---> 32                         callbacks=[ModelCheckpoint(monitor='val_loss', filepath=weight_path, verbose=1, save_best_only=True)])
#      33                                     #EarlyStopping(monitor='val_loss', patience=7, verbose=0, mode='auto')])
#      34
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1096                 batch_size=batch_size):
#    1097               callbacks.on_train_batch_begin(step)
# -> 1098               tmp_logs = train_function(iterator)
#    1099               if data_handler.should_sync:
#    1100                 context.async_wait()
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     778       else:
#     779         compiler = "nonXla"
# --> 780         result = self._call(*args, **kwds)
#     781
#     782       new_tracing_count = self._get_tracing_count()
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     805       # In this case we have created variables on the first call, so we run the
#     806       # defunned version which is guaranteed to never create variables.
# --> 807       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     808     elif self._stateful_fn is not None:
#     809       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2827     with self._lock:
#    2828       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2829     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2830
#    2831   @property
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs, cancellation_manager)
#    1846                            resource_variable_ops.BaseResourceVariable))],
#    1847         captured_inputs=self.captured_inputs,
# -> 1848         cancellation_manager=cancellation_manager)
#    1849
#    1850   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1922       # No tape is watching; skip to running the function.
#    1923       return self._build_call_outputs(self._inference_function.call(
# -> 1924           ctx, args, cancellation_manager=cancellation_manager))
#    1925     forward_backward = self._select_forward_and_backward_functions(
#    1926         args,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     548               inputs=args,
#     549               attrs=attrs,
# --> 550               ctx=ctx)
#     551         else:
#     552           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %%
model_y = np.where(y_pred<0.5,0,1)
np.mean(model_y==y_test)
# Out:
# 0.7793647687993217

# %%
from tensorflow.python.client import device_lib

print(device_lib.list_local_devices())

from keras import backend as K

K.tensorflow_backend._get_available_gpus()
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 15237019909137396192
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 15763526327902109785
# physical_device_desc: "device: XLA_CPU device"
# ]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-102-2aeec309030e> in <module>
#       5 from keras import backend as K
#       6
# ----> 7 K.tensorflow_backend._get_available_gpus()
#
# AttributeError: module 'keras.backend' has no attribute 'tensorflow_backend'

# %%
hist = model.fit(x_train, y_train, validation_split=0.1, epochs=100, batch_size=BATCH_SIZE, class_weight={0:1, 1:10}, 
                        callbacks=[ModelCheckpoint(monitor='val_loss', filepath=weight_path, verbose=1, save_best_only=True),
                                    EarlyStopping(monitor='val_loss', patience=2, verbose=0, mode='auto')])

# 모델을 저장
open(odir + "/model.json", "wt").write(model.to_json())
